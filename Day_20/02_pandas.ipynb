# %% [markdown]
# ## Pandas
#
# - analyze 2d and multidimensional data
# - table like data
# - internally they use numpy

# %%
import pandas as pd

# %%
data = {
    'name': ['chleo', 'anita', 'diyali', 'ethan'],
    'age': [26, 21, 22, 25],
    'city': ['cape town', 'joburg', 'durban', 'cape town']
}

# %% [markdown]
# ## creating data frame

# %%
df = pd.DataFrame(data)

# %%
df['name']
# Out:
# 0     chleo
# 1     anita
# 2    diyali
# 3     ethan
# Name: name, dtype: object

# %%
df.head(2)
# Out:
#     name  age       city
# 0  chleo   26  cape town
# 1  anita   21     joburg

# %%
import numpy as np

# %%
items = np.array(
    [
        " Apple",
        "banana ",
        "GRAPE",
        "cucumber",
        "Pineapple",
        " tomato ",
        "Orange",
        " lemon",
        "Kiwi ",
        "mango",
        "blueberry ",
        " raspberry",
    ]
)
print(type(items))
print(type(items[0]))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.str_'>

# %%
hourly_visitors = np.array([468, 279, 73, 272, 406, 128, 302, 216, 140, 82])

print(type(hourly_visitors))
print(type(hourly_visitors[0]))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.int64'>

# %% [markdown]
# # Info about data
# - Columns
# - Datatype
# - Space occupied
# - Null
# - Fell for the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    4 non-null      object
#  1   age     4 non-null      int64
#  2   city    4 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 228.0+ bytes

# %%
df
# Out:
#      name  age       city
# 0   chleo   26  cape town
# 1   anita   21     joburg
# 2  diyali   22     durban
# 3   ethan   25  cape town

# %%
#df.shape  # (rows, columns)
#df.dtypes  # DataType
#df.columns
#df.describe()
#df.describe(include="all")  # Force all the columns
#people_df = df.describe(include="all")

#people_df["City"]

# %%
tips_df = pd.read_csv("./tips.csv")

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips_df["smoker"].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
tips_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
tips_df.describe(include = "all")
# Out:
#         total_bill         tip   sex smoker  day    time        size
# count   244.000000  244.000000   244    244  244     244  244.000000
# unique         NaN         NaN     2      2    4       2         NaN
# top            NaN         NaN  Male     No  Sat  Dinner         NaN
# freq           NaN         NaN   157    151   87     176         NaN
# mean     19.785943    2.998279   NaN    NaN  NaN     NaN    2.569672
# std       8.902412    1.383638   NaN    NaN  NaN     NaN    0.951100
# min       3.070000    1.000000   NaN    NaN  NaN     NaN    1.000000
# 25%      13.347500    2.000000   NaN    NaN  NaN     NaN    2.000000
# 50%      17.795000    2.900000   NaN    NaN  NaN     NaN    2.000000
# 75%      24.127500    3.562500   NaN    NaN  NaN     NaN    3.000000
# max      50.810000   10.000000   NaN    NaN  NaN     NaN    6.000000

# %%
tips_df[['day', 'time', 'time']]
# Out:
#       day    time    time
# 0     Sun  Dinner  Dinner
# 1     Sun  Dinner  Dinner
# 2     Sun  Dinner  Dinner
# 3     Sun  Dinner  Dinner
# 4     Sun  Dinner  Dinner
# ..    ...     ...     ...
# 239   Sat  Dinner  Dinner
# 240   Sat  Dinner  Dinner
# 241   Sat  Dinner  Dinner
# 242   Sat  Dinner  Dinner
# 243  Thur  Dinner  Dinner
#
# [244 rows x 3 columns]

# %%
tips_df[["day", "time", "time"]].head(10)
# Out:
#    day    time    time
# 0  Sun  Dinner  Dinner
# 1  Sun  Dinner  Dinner
# 2  Sun  Dinner  Dinner
# 3  Sun  Dinner  Dinner
# 4  Sun  Dinner  Dinner
# 5  Sun  Dinner  Dinner
# 6  Sun  Dinner  Dinner
# 7  Sun  Dinner  Dinner
# 8  Sun  Dinner  Dinner
# 9  Sun  Dinner  Dinner

# %%
tips_df['tips_per_person'] = tips_df['tip']/tips_df['size' ]  # added this column

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size  tips_per_person
# 0         16.99  1.01  Female     No   Sun  Dinner     2         0.505000
# 1         10.34  1.66    Male     No   Sun  Dinner     3         0.553333
# 2         21.01  3.50    Male     No   Sun  Dinner     3         1.166667
# 3         23.68  3.31    Male     No   Sun  Dinner     2         1.655000
# 4         24.59  3.61  Female     No   Sun  Dinner     4         0.902500
# ..          ...   ...     ...    ...   ...     ...   ...              ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3         1.973333
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2         1.000000
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2         1.000000
# 242       17.82  1.75    Male     No   Sat  Dinner     2         0.875000
# 243       18.78  3.00  Female     No  Thur  Dinner     2         1.500000
#
# [244 rows x 8 columns]

# %%
tips_df["tip_percentage"] = round(tips_df["tip"] / tips_df["total_bill"] * 100, 2)

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size  tips_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2         0.505000
# 1         10.34  1.66    Male     No   Sun  Dinner     3         0.553333
# 2         21.01  3.50    Male     No   Sun  Dinner     3         1.166667
# 3         23.68  3.31    Male     No   Sun  Dinner     2         1.655000
# 4         24.59  3.61  Female     No   Sun  Dinner     4         0.902500
# ..          ...   ...     ...    ...   ...     ...   ...              ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3         1.973333
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2         1.000000
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2         1.000000
# 242       17.82  1.75    Male     No   Sat  Dinner     2         0.875000
# 243       18.78  3.00  Female     No  Thur  Dinner     2         1.500000
#
#      tip_percentage
# 0              5.94
# 1             16.05
# ...

# %%
tips_df[tips_df["day"] == "Sun"]
# Out:
#      total_bill   tip     sex smoker  day    time  size  tips_per_person  \
# 0         16.99  1.01  Female     No  Sun  Dinner     2         0.505000
# 1         10.34  1.66    Male     No  Sun  Dinner     3         0.553333
# 2         21.01  3.50    Male     No  Sun  Dinner     3         1.166667
# 3         23.68  3.31    Male     No  Sun  Dinner     2         1.655000
# 4         24.59  3.61  Female     No  Sun  Dinner     4         0.902500
# ..          ...   ...     ...    ...  ...     ...   ...              ...
# 186       20.90  3.50  Female    Yes  Sun  Dinner     3         1.166667
# 187       30.46  2.00    Male    Yes  Sun  Dinner     5         0.400000
# 188       18.15  3.50  Female    Yes  Sun  Dinner     3         1.166667
# 189       23.10  4.00    Male    Yes  Sun  Dinner     3         1.333333
# 190       15.69  1.50    Male    Yes  Sun  Dinner     2         0.750000
#
#      tip_percentage
# 0              5.94
# 1             16.05
# 2             16.66
# ...

# %%
tips_df[(tips_df["tip"] > 3) & (tips_df["day"] == "Fri")]
# Out:
#      total_bill   tip     sex smoker  day    time  size  tips_per_person  \
# 91        22.49  3.50    Male     No  Fri  Dinner     2           1.7500
# 93        16.32  4.30  Female    Yes  Fri  Dinner     2           2.1500
# 94        22.75  3.25  Female     No  Fri  Dinner     2           1.6250
# 95        40.17  4.73    Male    Yes  Fri  Dinner     4           1.1825
# 96        27.28  4.00    Male    Yes  Fri  Dinner     2           2.0000
# 221       13.42  3.48  Female    Yes  Fri   Lunch     2           1.7400
#
#      tip_percentage
# 91            15.56
# 93            26.35
# 94            14.29
# 95            11.77
# 96            14.66
# 221           25.93

# %%
tips_df[tips_df["day"] == "Fri"][tips_df["tip"]>3]
# Out:
# C:\Users\E1009807\AppData\Local\Temp\ipykernel_22808\251249752.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   tips_df[tips_df["day"] == "Fri"][tips_df["tip"]>3]
#      total_bill   tip     sex smoker  day    time  size  tips_per_person  \
# 91        22.49  3.50    Male     No  Fri  Dinner     2           1.7500
# 93        16.32  4.30  Female    Yes  Fri  Dinner     2           2.1500
# 94        22.75  3.25  Female     No  Fri  Dinner     2           1.6250
# 95        40.17  4.73    Male    Yes  Fri  Dinner     4           1.1825
# 96        27.28  4.00    Male    Yes  Fri  Dinner     2           2.0000
# 221       13.42  3.48  Female    Yes  Fri   Lunch     2           1.7400
#
#      tip_percentage
# 91            15.56
# 93            26.35
# 94            14.29
# 95            11.77
# 96            14.66
# 221           25.93

# %%
tip_friday = tips_df[(tips_df["tip"] > 3) & (tips_df["day"] == "Fri")]

#binary & and | performing and on a binary level

# %%
tip_friday.sort_values(by="tip", ascending = False).head()
# Out:
#      total_bill   tip     sex smoker  day    time  size  tips_per_person  \
# 95        40.17  4.73    Male    Yes  Fri  Dinner     4           1.1825
# 93        16.32  4.30  Female    Yes  Fri  Dinner     2           2.1500
# 96        27.28  4.00    Male    Yes  Fri  Dinner     2           2.0000
# 91        22.49  3.50    Male     No  Fri  Dinner     2           1.7500
# 221       13.42  3.48  Female    Yes  Fri   Lunch     2           1.7400
#
#      tip_percentage
# 95            11.77
# 93            26.35
# 96            14.66
# 91            15.56
# 221           25.93

# %%
tips_df[(tips_df["size"] >= 5)|(tips_df["total_bill"] >= 35)]
# Out:
#      total_bill    tip     sex smoker   day    time  size  tips_per_person  \
# 11        35.26   5.00  Female     No   Sun  Dinner     4         1.250000
# 23        39.42   7.58    Male     No   Sat  Dinner     4         1.895000
# 56        38.01   3.00    Male    Yes   Sat  Dinner     4         0.750000
# 59        48.27   6.73    Male     No   Sat  Dinner     4         1.682500
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4         1.182500
# 102       44.30   2.50  Female    Yes   Sat  Dinner     3         0.833333
# 112       38.07   4.00    Male     No   Sun  Dinner     3         1.333333
# 125       29.80   4.20  Female     No  Thur   Lunch     6         0.700000
# 141       34.30   6.70    Male     No  Thur   Lunch     6         1.116667
# 142       41.19   5.00    Male     No  Thur   Lunch     5         1.000000
# 143       27.05   5.00  Female     No  Thur   Lunch     6         0.833333
# ...

# %% [markdown]
# ## slicing
#
# - loc : based on name  --> mix of offset and slice
# - iloc :based on index
# - tail
# - head

# %%
tips_df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  tips_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2         0.505000
# 1       10.34  1.66    Male     No  Sun  Dinner     3         0.553333
# 2       21.01  3.50    Male     No  Sun  Dinner     3         1.166667
# 3       23.68  3.31    Male     No  Sun  Dinner     2         1.655000
# 4       24.59  3.61  Female     No  Sun  Dinner     4         0.902500
#
#    tip_percentage
# 0            5.94
# 1           16.05
# 2           16.66
# 3           13.98
# 4           14.68

# %%
tips_df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size  tips_per_person  \
# 239       29.03  5.92    Male     No   Sat  Dinner     3         1.973333
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2         1.000000
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2         1.000000
# 242       17.82  1.75    Male     No   Sat  Dinner     2         0.875000
# 243       18.78  3.00  Female     No  Thur  Dinner     2         1.500000
#
#      tip_percentage
# 239           20.39
# 240            7.36
# 241            8.82
# 242            9.82
# 243           15.97

# %%
tips_df.iloc[3]
# Out:
# total_bill          23.68
# tip                  3.31
# sex                  Male
# smoker                 No
# day                   Sun
# time               Dinner
# size                    2
# tips_per_person     1.655
# tip_percentage      13.98
# Name: 3, dtype: object

# %%
tips_df.iloc[3:5] #slice of row
# Out:
#    total_bill   tip     sex smoker  day    time  size  tips_per_person  \
# 3       23.68  3.31    Male     No  Sun  Dinner     2           1.6550
# 4       24.59  3.61  Female     No  Sun  Dinner     4           0.9025
#
#    tip_percentage
# 3           13.98
# 4           14.68

# %%
tips_df.loc[3]
# Out:
# total_bill          23.68
# tip                  3.31
# sex                  Male
# smoker                 No
# day                   Sun
# time               Dinner
# size                    2
# tips_per_person     1.655
# tip_percentage      13.98
# Name: 3, dtype: object

# %%
tips_df.loc[3:5] # matches name "3, 4 , 5"
# Out:
#    total_bill   tip     sex smoker  day    time  size  tips_per_person  \
# 3       23.68  3.31    Male     No  Sun  Dinner     2           1.6550
# 4       24.59  3.61  Female     No  Sun  Dinner     4           0.9025
# 5       25.29  4.71    Male     No  Sun  Dinner     4           1.1775
#
#    tip_percentage
# 3           13.98
# 4           14.68
# 5           18.62

# %%
tips_df.tail(6)
# Out:
#      total_bill   tip     sex smoker   day    time  size  tips_per_person  \
# 238       35.83  4.67  Female     No   Sat  Dinner     3         1.556667
# 239       29.03  5.92    Male     No   Sat  Dinner     3         1.973333
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2         1.000000
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2         1.000000
# 242       17.82  1.75    Male     No   Sat  Dinner     2         0.875000
# 243       18.78  3.00  Female     No  Thur  Dinner     2         1.500000
#
#      tip_percentage
# 238           13.03
# 239           20.39
# 240            7.36
# 241            8.82
# 242            9.82
# 243           15.97

# %%
tips_df.tail(6).loc[240:241]
# Out:
#      total_bill  tip     sex smoker  day    time  size  tips_per_person  \
# 240       27.18  2.0  Female    Yes  Sat  Dinner     2              1.0
# 241       22.67  2.0    Male    Yes  Sat  Dinner     2              1.0
#
#      tip_percentage
# 240            7.36
# 241            8.82

# %%
tips_df.tail(6).iloc[2:4]
# Out:
#      total_bill  tip     sex smoker  day    time  size  tips_per_person  \
# 240       27.18  2.0  Female    Yes  Sat  Dinner     2              1.0
# 241       22.67  2.0    Male    Yes  Sat  Dinner     2              1.0
#
#      tip_percentage
# 240            7.36
# 241            8.82

# %%
tips_df.tail(6).loc[-4:-2, ["tip", "time"]]
# Out:
# Empty DataFrame
# Columns: [tip, time]
# Index: []
